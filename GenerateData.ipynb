# %%
from __future__ import print_function
import argparse
import datetime
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML
from IPython.display import clear_output
from tqdm import tqdm
import cv2

import torch
import torch.nn as nn
import torch.nn.parallel
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torchvision import transforms
import torchvision.utils as vutils
from torchvision.utils import save_image
from torch.autograd import Variable
import matplotlib.colors as mat_color
from torch.utils.data import SubsetRandomSampler

# %%
for func in [
    lambda: os.mkdir(os.path.join('.', 'GANGEN')),
    lambda: os.mkdir(os.path.join('.', 'GANGEN/Covid')),
    lambda: os.mkdir(os.path.join('.', 'GANGEN/Normal')),
    lambda: os.mkdir(os.path.join('.', 'GANGEN/Viral Pneumonia'))]:  # create directories
    try:
        func()
    except Exception as error:
        print(error)
        continue
# Out:
# [Errno 17] File exists: './GANGEN'
# [Errno 17] File exists: './GANGEN/Covid'
# [Errno 17] File exists: './GANGEN/Normal'
# [Errno 17] File exists: './GANGEN/Viral Pneumonia'

# %%
select_epoch = 12
generator_path = "GANAug/model/ACGAN/G_epoch_" + str(select_epoch) + ".pth"
discriminator_path = "GANAug/model/ACGAN/D_epoch_" + str(select_epoch) + ".pth"
no_norm = mat_color.Normalize(vmin=0, vmax=255, clip=False)

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)

class Generator(nn.Module):

    def __init__(self, nz, ngf, nc):

        super(Generator, self).__init__()
        self.ReLU = nn.ReLU(True)
        self.Tanh = nn.Tanh()
        self.conv1 = nn.ConvTranspose2d(nz, ngf * 8, 4, 1, 0, bias=False)
        self.BatchNorm1 = nn.BatchNorm2d(ngf * 8)

        self.conv2 = nn.ConvTranspose2d(ngf * 8, ngf * 8, 4, 2, 1, bias=False)
        self.BatchNorm2 = nn.BatchNorm2d(ngf * 8)

        self.conv3 = nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False)
        self.BatchNorm3 = nn.BatchNorm2d(ngf * 4)

        self.conv4 = nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False)
        self.BatchNorm4 = nn.BatchNorm2d(ngf * 2)
        
        self.conv5 = nn.ConvTranspose2d(ngf * 2, ngf * 1, 4, 2, 1, bias=False)
        self.BatchNorm5 = nn.BatchNorm2d(ngf * 1)

        self.conv6 = nn.ConvTranspose2d(ngf * 1, nc, 4, 2, 1, bias=False)

        self.apply(weights_init)


    def forward(self, input):
        x = self.conv1(input)
        x = self.BatchNorm1(x)
        x = self.ReLU(x)
        
        x = self.conv2(x)
        x = self.BatchNorm2(x)
        x = self.ReLU(x)

        x = self.conv3(x)
        x = self.BatchNorm3(x)
        x = self.ReLU(x)

        x = self.conv4(x)
        x = self.BatchNorm4(x)
        x = self.ReLU(x)

        x = self.conv5(x)
        x = self.BatchNorm5(x)
        x = self.ReLU(x)

        x = self.conv6(x)
        output = self.Tanh(x)
        return output

class Discriminator(nn.Module):

    def __init__(self, ndf, nc, nb_label):

        super(Discriminator, self).__init__()
        self.LeakyReLU = nn.LeakyReLU(0.2, inplace=True)
        self.DropOut1 = nn.Dropout(p=0.5)
        self.DropOut2 = nn.Dropout(p=0.25)
        self.conv1 = nn.Conv2d(nc, ndf, 4, 2, 1, bias=False)
        self.BatchNorm1 = nn.BatchNorm2d(ndf)
        self.conv2 = nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False)
        self.BatchNorm2 = nn.BatchNorm2d(ndf * 2)
        self.conv3 = nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False)
        self.BatchNorm3 = nn.BatchNorm2d(ndf * 4)
        self.conv4_1 = nn.Conv2d(ndf * 4, ndf * 4, 4, 2, 1, bias=False)
        self.BatchNorm4_1 = nn.BatchNorm2d(ndf * 4)
        self.conv4_2 = nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False)
        self.BatchNorm4_2 = nn.BatchNorm2d(ndf * 8)
        self.conv4_3 = nn.Conv2d(ndf * 8, ndf * 8, 4, 2, 1, bias=False)
        self.BatchNorm4_3 = nn.BatchNorm2d(ndf * 8)
        self.conv5 = nn.Conv2d(ndf * 8, ndf * 1, 4, 1, 0, bias=False)
        self.disc_linear = nn.Linear(ndf * 1, 1)
        self.aux_linear = nn.Linear(ndf * 1, nb_label)
        self.softmax = nn.LogSoftmax()
        self.sigmoid = nn.Sigmoid()
        self.ndf = ndf
        self.apply(weights_init)

    def forward(self, input):

        x = self.conv1(input)
        x = self.BatchNorm1(x)
        x = self.LeakyReLU(x)
        x = self.DropOut2(x)

        x = self.conv2(x)
        x = self.BatchNorm2(x)
        x = self.LeakyReLU(x)
        x = self.DropOut2(x)

        x = self.conv3(x)
        x = self.BatchNorm3(x)
        x = self.LeakyReLU(x)
        x = self.DropOut2(x)

        x = self.conv4_2(x)
        x = self.BatchNorm4_2(x)
        x = self.LeakyReLU(x)
        x = self.DropOut2(x)
        x = self.conv4_3(x)
        x = self.BatchNorm4_3(x)
        x = self.LeakyReLU(x)
        x = self.DropOut2(x)

        x = self.conv5(x)
        x = x.view(-1, self.ndf * 1)
        c = self.aux_linear(x)
        c = self.softmax(c)
        s = self.disc_linear(x)
        s = self.sigmoid(s)
        return s, c

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
imageSize = 128

# Number of channels in the training images. For color images this is 3
# nc = 3
nc = 1

# Size of z latent vector (i.e. size of generator input)
# nz = 300 # v1
# nz = 400 # v2
nz = 512 # v3 & v4

# Size of feature maps in generator
ngf = 128

# Size of feature maps in discriminator
ndf = 128

# No of labels
nb_label = 3

generator = Generator(nz, ngf, nc).to(device)
discriminator = Discriminator(ndf, nc, nb_label).to(device)

# %%
generator.load_state_dict(torch.load(generator_path))
discriminator.load_state_dict(torch.load(discriminator_path))
# Out:
# <All keys matched successfully>

# %%
generator
# Out:
# Generator(
#   (ReLU): ReLU(inplace=True)
#   (Tanh): Tanh()
#   (conv1): ConvTranspose2d(512, 1024, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (BatchNorm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): ConvTranspose2d(1024, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): ConvTranspose2d(128, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
# )

# %%
discriminator
# Out:
# Discriminator(
#   (LeakyReLU): LeakyReLU(negative_slope=0.2, inplace=True)
#   (DropOut1): Dropout(p=0.5, inplace=False)
#   (DropOut2): Dropout(p=0.25, inplace=False)
#   (conv1): Conv2d(1, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4_1): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm4_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4_2): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm4_2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4_3): Conv2d(1024, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm4_3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(1024, 128, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (disc_linear): Linear(in_features=128, out_features=1, bias=True)
#   (aux_linear): Linear(in_features=128, out_features=3, bias=True)
#   (softmax): LogSoftmax(dim=None)
#   (sigmoid): Sigmoid()
# )

# %%
label_dict = {
    0: "Covid",
    1: "Normal",
    2: "Viral Pneumonia"
}

label_count = {
    0: 0,
    1: 0,
    2: 0
}

# %%
def process_abnormal(c):
    cc = np.array(torch.argmax(c, dim=1).detach().cpu())
    size = len(c)
    count = 0
    for i in range(size):
        if max(c[i]) <= np.log(0.99):
            cc[i] = -1
            count += 1
    print(count/size)
    return cc

# %%
def generate_and_save(generator, discriminator, batch_size, path):
    # classes (list): List of the class names sorted alphabetically.
    test_noise = torch.randn(batch_size, nz, 1, 1, device=device)
    test_fake = generator(test_noise)
    now = datetime.datetime.now()
    s, c = discriminator(test_fake)
    c = process_abnormal(c)
    for i in range(batch_size):
        if c[i] == -1:
            print("too bad, man")
            continue
        label = label_dict[c[i]]
        label_count[c[i]] += 1
        image = test_fake[i].detach().cpu()
        image_show = np.transpose(test_fake[i].detach().cpu(), (1, 2, 0))
        # plt.imshow(image_show, 'gray')
        print(os.path.join(os.path.join(path, label), "CACGAN_" + str(label_count[c[i]]) + ".jpg"))
        vutils.save_image(image.data, os.path.join(os.path.join(path, label), "CACGAN_" + str(label_count[c[i]]) + "_" + now.strftime("%Y-%m-%d_%H-%M-%S") + ".png"),
                         normalize=True)

# %%
total_num = 251 * 5
variety = 50 * 5
batch_size = round(total_num/variety)

# %%
for i in range(variety):
    generate_and_save(generator, discriminator, batch_size=batch_size, path=os.path.join('.', 'GANGEN'))
# Out:
# /tmp/ipykernel_16510/1298441974.py:118: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   c = self.softmax(c)
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_1.jpg
# ./GANGEN/Covid/CACGAN_2.jpg
# ./GANGEN/Covid/CACGAN_3.jpg
# too bad, man
# 0.8
# too bad, man
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_4.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_5.jpg
# ./GANGEN/Covid/CACGAN_6.jpg
# ./GANGEN/Covid/CACGAN_7.jpg
# too bad, man
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_8.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_9.jpg
# ./GANGEN/Covid/CACGAN_10.jpg
# ./GANGEN/Covid/CACGAN_11.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_12.jpg
# ./GANGEN/Covid/CACGAN_13.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_14.jpg
# ./GANGEN/Covid/CACGAN_15.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_16.jpg
# ./GANGEN/Covid/CACGAN_17.jpg
# ./GANGEN/Covid/CACGAN_18.jpg
# ./GANGEN/Covid/CACGAN_19.jpg
# too bad, man
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_20.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_21.jpg
# ./GANGEN/Covid/CACGAN_22.jpg
# 0.4
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_23.jpg
# ./GANGEN/Covid/CACGAN_24.jpg
# ./GANGEN/Covid/CACGAN_25.jpg
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_26.jpg
# ./GANGEN/Covid/CACGAN_27.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_28.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_29.jpg
# ./GANGEN/Covid/CACGAN_30.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_31.jpg
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_32.jpg
# ./GANGEN/Covid/CACGAN_33.jpg
# ./GANGEN/Covid/CACGAN_34.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_35.jpg
# 0.8
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_36.jpg
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_37.jpg
# ./GANGEN/Viral Pneumonia/CACGAN_1.jpg
# ./GANGEN/Covid/CACGAN_38.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_39.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_40.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_41.jpg
# ./GANGEN/Covid/CACGAN_42.jpg
# ./GANGEN/Covid/CACGAN_43.jpg
# 0.6
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_44.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_45.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_46.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_47.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_48.jpg
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN
jpg
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_332.jpg
# ./GANGEN/Covid/CACGAN_333.jpg
# ./GANGEN/Covid/CACGAN_334.jpg
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_335.jpg
# ./GANGEN/Covid/CACGAN_336.jpg
# ./GANGEN/Covid/CACGAN_337.jpg
# ./GANGEN/Covid/CACGAN_338.jpg
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_339.jpg
# ./GANGEN/Covid/CACGAN_340.jpg
# ./GANGEN/Covid/CACGAN_341.jpg
# too bad, man
# too bad, man
# 0.0
# ./GANGEN/Covid/CACGAN_342.jpg
# ./GANGEN/Covid/CACGAN_343.jpg
# ./GANGEN/Covid/CACGAN_344.jpg
# ./GANGEN/Covid/CACGAN_345.jpg
# ./GANGEN/Covid/CACGAN_346.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_347.jpg
# ./GANGEN/Covid/CACGAN_348.jpg
# ./GANGEN/Viral Pneumonia/CACGAN_11.jpg
# ./GANGEN/Covid/CACGAN_349.jpg
# too bad, man
# 0.6
# ./GANGEN/Covid/CACGAN_350.jpg
# ./GANGEN/Covid/CACGAN_351.jpg
# too bad, man
# too bad, man
# too bad, man
# 0.8
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_352.jpg
# too bad, man
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_353.jpg
# ./GANGEN/Covid/CACGAN_354.jpg
# ./GANGEN/Covid/CACGAN_355.jpg
# too bad, man
# 0.6
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_356.jpg
# ./GANGEN/Covid/CACGAN_357.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_358.jpg
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_359.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_360.jpg
# ./GANGEN/Covid/CACGAN_361.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_362.jpg
# too bad, man
# 0.6
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_363.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_364.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_365.jpg
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Viral Pneumonia/CACGAN_12.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_366.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_367.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_368.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_369.jpg
# ./GANGEN/Covid/CACGAN_370.jpg
# ./GANGEN/Covid/CACGAN_371.jpg
# ./GANGEN/Covid/CACGAN_372.jpg
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_373.jpg
# ./GANGEN/Covid/CACGAN_374.jpg
# ./GANGEN/Covid/CACGAN_375.jpg
# ./GANGEN/Covid/CACGAN_376.jpg
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_377.jpg
# ./GANGEN/Covid/CACGAN_378.jpg
# ./GANGEN/Covid/CACGAN_379.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_380.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_381.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_382.jpg
# ./GANGEN/Covid/CACGAN_383.jpg
# too bad, man
# 0.8
# too bad, man
# ./GANGEN/Covid/CACGAN_384.jpg
# too bad, man
# too bad, man
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_385.jpg
# ./GANGEN/Covid/CACGAN_386.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_387.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_388.jpg
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_389.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_390.jpg
# ./GANGEN/Covid/CACGAN_391.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_392.jpg
# too bad, man
# 0.8
# too bad, man
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_393.jpg
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_394.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_395.jpg
# too bad, man
# 0.6
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_396.jpg
# ./GANGEN/Covid/CACGAN_397.jpg
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_398.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_399.jpg
# ./GANGEN/Covid/CACGAN_400.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_401.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_402.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_403.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_404.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_405.jpg
# too bad, man
# too bad, man
# 0.6
# ./GANGEN/Covid/CACGAN_406.jpg
# ./GANGEN/Covid/CACGAN_407.jpg
# too bad, man
# too bad, man
# too bad, man
# 0.2
# too bad, man
# ./GANGEN/Covid/CACGAN_408.jpg
# ./GANGEN/Covid/CACGAN_409.jpg
# ./GANGEN/Covid/CACGAN_410.jpg
# ./GANGEN/Covid/CACGAN_411.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_412.jpg
# ./GANGEN/Covid/CACGAN_413.jpg
# ./GANGEN/Covid/CACGAN_414.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_415.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_416.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_417.jpg
# too bad, man
# 0.6
# ./GANGEN/Covid/CACGAN_418.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_419.jpg
# too bad, man
# too bad, man
# 0.8
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_420.jpg
# too bad, man
# too bad, man
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_421.jpg
# ./GANGEN/Covid/CACGAN_422.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_423.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_424.jpg
# ./GANGEN/Covid/CACGAN_425.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_426.jpg
# ./GANGEN/Covid/CACGAN_427.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_428.jpg
# ./GANGEN/Covid/CACGAN_429.jpg
# ./GANGEN/Covid/CACGAN_430.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_431.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_432.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_433.jpg
# ./GANGEN/Covid/CACGAN_434.jpg
# ./GANGEN/Covid/CACGAN_435.jpg
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_436.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_437.jpg
# ./GANGEN/Covid/CACGAN_438.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_439.jpg
# ./GANGEN/Covid/CACGAN_440.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_441.jpg
# ./GANGEN/Covid/CACGAN_442.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_443.jpg
# ./GANGEN/Covid/CACGAN_444.jpg
# too bad, man
# too bad, man
# too bad, man
# 0.8
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_445.jpg
# too bad, man
# 0.6
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_446.jpg
# ./GANGEN/Covid/CACGAN_447.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_448.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_449.jpg
# ./GANGEN/Covid/CACGAN_450.jpg
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_451.jpg
# too bad, man
# ./GANGEN/Viral Pneumonia/CACGAN_13.jpg
# ./GANGEN/Covid/CACGAN_452.jpg
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_453.jpg
# ./GANGEN/Covid/CACGAN_454.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_455.jpg
# 0.6
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_456.jpg
# ./GANGEN/Covid/CACGAN_457.jpg
# too bad, man
# 0.6
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_458.jpg
# ./GANGEN/Covid/CACGAN_459.jpg
# 0.8
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_460.jpg
# too bad, man
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_461.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_462.jpg
# ./GANGEN/Covid/CACGAN_463.jpg
# ./GANGEN/Covid/CACGAN_464.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_465.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_466.jpg
# ./GANGEN/Covid/CACGAN_467.jpg
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_468.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_469.jpg
# ./GANGEN/Covid/CACGAN_470.jpg
# ./GANGEN/Covid/CACGAN_471.jpg
# 0.2
# too bad, man
# ./GANGEN/Covid/CACGAN_472.jpg
# ./GANGEN/Covid/CACGAN_473.jpg
# ./GANGEN/Covid/CACGAN_474.jpg
# ./GANGEN/Covid/CACGAN_475.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_476.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_477.jpg
# ./GANGEN/Covid/CACGAN_478.jpg
# ./GANGEN/Covid/CACGAN_479.jpg
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_480.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_481.jpg
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_482.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_483.jpg
# too bad, man
# 0.6
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_484.jpg
# ./GANGEN/Covid/CACGAN_485.jpg
# too bad, man
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_486.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_487.jpg
# too bad, man
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_488.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_489.jpg
# 0.8
# ./GANGEN/Covid/CACGAN_490.jpg
# too bad, man
# too bad, man
# too bad, man
# too bad, man
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_491.jpg
# ./GANGEN/Covid/CACGAN_492.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_493.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_494.jpg
# ./GANGEN/Covid/CACGAN_495.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_496.jpg
# ./GANGEN/Covid/CACGAN_497.jpg
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_498.jpg
# ./GANGEN/Covid/CACGAN_499.jpg
# too bad, man
# too bad, man
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_500.jpg
# ./GANGEN/Covid/CACGAN_501.jpg
# ./GANGEN/Covid/CACGAN_502.jpg
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_503.jpg
# ./GANGEN/Covid/CACGAN_504.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_505.jpg
# 0.2
# too bad, man
# ./GANGEN/Covid/CACGAN_506.jpg
# ./GANGEN/Covid/CACGAN_507.jpg
# ./GANGEN/Covid/CACGAN_508.jpg
# ./GANGEN/Covid/CACGAN_509.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_510.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_511.jpg
# too bad, man
# too bad, man
# 0.6
# ./GANGEN/Covid/CACGAN_512.jpg
# ./GANGEN/Viral Pneumonia/CACGAN_14.jpg
# too bad, man
# too bad, man
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_513.jpg
# ./GANGEN/Covid/CACGAN_514.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_515.jpg
# ./GANGEN/Covid/CACGAN_516.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_517.jpg
# ./GANGEN/Covid/CACGAN_518.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_519.jpg
# ./GANGEN/Covid/CACGAN_520.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_521.jpg
# ./GANGEN/Covid/CACGAN_522.jpg
# ./GANGEN/Covid/CACGAN_523.jpg
# ./GANGEN/Covid/CACGAN_524.jpg
# too bad, man
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_525.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_526.jpg
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_527.jpg
# ./GANGEN/Covid/CACGAN_528.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_529.jpg
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_530.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_531.jpg
# ./GANGEN/Covid/CACGAN_532.jpg
# ./GANGEN/Covid/CACGAN_533.jpg
# 0.0
# ./GANGEN/Covid/CACGAN_534.jpg
# ./GANGEN/Covid/CACGAN_535.jpg
# ./GANGEN/Covid/CACGAN_536.jpg
# ./GANGEN/Covid/CACGAN_537.jpg
# ./GANGEN/Covid/CACGAN_538.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_539.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_540.jpg
# too bad, man
# 0.6
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_541.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_542.jpg
# 0.2
# too bad, man
# ./GANGEN/Covid/CACGAN_543.jpg
# ./GANGEN/Covid/CACGAN_544.jpg
# ./GANGEN/Covid/CACGAN_545.jpg
# ./GANGEN/Covid/CACGAN_546.jpg
# 0.4
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_547.jpg
# ./GANGEN/Covid/CACGAN_548.jpg
# ./GANGEN/Covid/CACGAN_549.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_550.jpg
# ./GANGEN/Covid/CACGAN_551.jpg
# too bad, man
# too bad, man
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_552.jpg
# ./GANGEN/Covid/CACGAN_553.jpg
# ./GANGEN/Covid/CACGAN_554.jpg
# ./GANGEN/Covid/CACGAN_555.jpg
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_556.jpg
# ./GANGEN/Covid/CACGAN_557.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_558.jpg
# ./GANGEN/Covid/CACGAN_559.jpg
# 0.6
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_560.jpg
# ./GANGEN/Covid/CACGAN_561.jpg
# 1.0
# too bad, man
# too bad, man
# too bad, man
# too bad, man
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_562.jpg
# ./GANGEN/Covid/CACGAN_563.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_564.jpg
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_565.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_566.jpg
# ./GANGEN/Covid/CACGAN_567.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_568.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_569.jpg
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_570.jpg
# ./GANGEN/Covid/CACGAN_571.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_572.jpg
# too bad, man
# 0.6
# ./GANGEN/Covid/CACGAN_573.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_574.jpg
# too bad, man
# 0.0
# ./GANGEN/Covid/CACGAN_575.jpg
# ./GANGEN/Viral Pneumonia/CACGAN_15.jpg
# ./GANGEN/Covid/CACGAN_576.jpg
# ./GANGEN/Covid/CACGAN_577.jpg
# ./GANGEN/Covid/CACGAN_578.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_579.jpg
# ./GANGEN/Covid/CACGAN_580.jpg
# ./GANGEN/Covid/CACGAN_581.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_582.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_583.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_584.jpg
# ./GANGEN/Covid/CACGAN_585.jpg
# too bad, man
# 0.6
# ./GANGEN/Covid/CACGAN_586.jpg
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_587.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_588.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_589.jpg
# ./GANGEN/Covid/CACGAN_590.jpg
# 0.0
# ./GANGEN/Covid/CACGAN_591.jpg
# ./GANGEN/Covid/CACGAN_592.jpg
# ./GANGEN/Covid/CACGAN_593.jpg
# ./GANGEN/Covid/CACGAN_594.jpg
# ./GANGEN/Covid/CACGAN_595.jpg
# 0.2
# ./GANGEN/Viral Pneumonia/CACGAN_16.jpg
# ./GANGEN/Covid/CACGAN_596.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_597.jpg
# ./GANGEN/Covid/CACGAN_598.jpg
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_599.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_600.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_601.jpg
# ./GANGEN/Covid/CACGAN_602.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_603.jpg
# too bad, man
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_604.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_605.jpg
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_606.jpg
# ./GANGEN/Covid/CACGAN_607.jpg
# too bad, man
# too bad, man
# 0.8
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_608.jpg
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_609.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_610.jpg
# ./GANGEN/Covid/CACGAN_611.jpg
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_612.jpg
# ./GANGEN/Covid/CACGAN_613.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_614.jpg
# too bad, man
# 0.2
# ./GANGEN/Covid/CACGAN_615.jpg
# ./GANGEN/Covid/CACGAN_616.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_617.jpg
# ./GANGEN/Covid/CACGAN_618.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_619.jpg
# ./GANGEN/Covid/CACGAN_620.jpg
# ./GANGEN/Covid/CACGAN_621.jpg
# too bad, man
# too bad, man
# 0.4
# too bad, man
# ./GANGEN/Covid/CACGAN_622.jpg
# ./GANGEN/Covid/CACGAN_623.jpg
# ./GANGEN/Covid/CACGAN_624.jpg
# too bad, man
# 0.8
# too bad, man
# ./GANGEN/Covid/CACGAN_625.jpg
# too bad, man
# too bad, man
# too bad, man
# 0.6
# ./GANGEN/Covid/CACGAN_626.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_627.jpg
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_628.jpg
# ./GANGEN/Covid/CACGAN_629.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_630.jpg
# too bad, man
# 0.2
# too bad, man
# ./GANGEN/Covid/CACGAN_631.jpg
# ./GANGEN/Covid/CACGAN_632.jpg
# ./GANGEN/Covid/CACGAN_633.jpg
# ./GANGEN/Covid/CACGAN_634.jpg
# 0.8
# too bad, man
# ./GANGEN/Covid/CACGAN_635.jpg
# too bad, man
# too bad, man
# too bad, man
# 0.6
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_636.jpg
# ./GANGEN/Covid/CACGAN_637.jpg
# too bad, man
# 0.4
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_638.jpg
# ./GANGEN/Covid/CACGAN_639.jpg
# ./GANGEN/Covid/CACGAN_640.jpg
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_641.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_642.jpg
# too bad, man
# 0.8
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_643.jpg
# too bad, man
# too bad, man
# 0.8
# ./GANGEN/Covid/CACGAN_644.jpg
# too bad, man
# too bad, man
# too bad, man
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_645.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_646.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_647.jpg
# 0.4
# ./GANGEN/Covid/CACGAN_648.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_649.jpg
# ./GANGEN/Covid/CACGAN_650.jpg
# too bad, man
# 0.0
# ./GANGEN/Covid/CACGAN_651.jpg
# ./GANGEN/Covid/CACGAN_652.jpg
# ./GANGEN/Covid/CACGAN_653.jpg
# ./GANGEN/Covid/CACGAN_654.jpg
# ./GANGEN/Covid/CACGAN_655.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_656.jpg
# ./GANGEN/Covid/CACGAN_657.jpg
# too bad, man
# too bad, man
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_658.jpg
# ./GANGEN/Covid/CACGAN_659.jpg
# ./GANGEN/Covid/CACGAN_660.jpg
# too bad, man
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_661.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_662.jpg
# ./GANGEN/Covid/CACGAN_663.jpg
# too bad, man
# 0.0
# ./GANGEN/Covid/CACGAN_664.jpg
# ./GANGEN/Covid/CACGAN_665.jpg
# ./GANGEN/Covid/CACGAN_666.jpg
# ./GANGEN/Covid/CACGAN_667.jpg
# ./GANGEN/Covid/CACGAN_668.jpg
# 0.6
# ./GANGEN/Covid/CACGAN_669.jpg
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_670.jpg
# 0.6
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_671.jpg
# ./GANGEN/Covid/CACGAN_672.jpg
# 0.2
# ./GANGEN/Covid/CACGAN_673.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_674.jpg
# ./GANGEN/Covid/CACGAN_675.jpg
# ./GANGEN/Viral Pneumonia/CACGAN_17.jpg
# 0.6
# too bad, man
# too bad, man
# ./GANGEN/Viral Pneumonia/CACGAN_18.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_676.jpg
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_677.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_678.jpg
# too bad, man
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_679.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_680.jpg
# too bad, man
# 0.8
# too bad, man
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_681.jpg
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_682.jpg
# too bad, man
# ./GANGEN/Covid/CACGAN_683.jpg
# ./GANGEN/Covid/CACGAN_684.jpg
# too bad, man
# 0.6
# ./GANGEN/Covid/CACGAN_685.jpg
# too bad, man
# too bad, man
# ./GANGEN/Covid/CACGAN_686.jpg
# too bad, man
# 0.6
# too bad, man
# ./GANGEN/Covid/CACGAN_687.jpg
# ./GANGEN/Covid/CACGAN_688.jpg
# too bad, man
# too bad, man
# 0.4
# ./GANGEN/Covid/CACGAN_689.jpg
# ./GANGEN/Covid/CACGAN_690.jpg
# too bad, man
# ./GANGEN/Viral Pneumonia/CACGAN_19.jpg
# too bad, man
